# %%
import twint
import nest_asyncio

nest_asyncio.apply()

twi = twint.Config()

twi.Search = 'Tedak Sinten'
twi.Lang = "ina"
twi.Store_json = True
twi.Output = 'Data/Indonesia(Tedak Sinten).json'
twi.Limit = 2000
twi.Since = "2015-09-05"
twi.Until = "2020-09-05"
twint.run.Search(twi)
# Out:
# 1301333219296460800 2020-09-03 08:36:31 SE Asia Standard Time <ambrosya1> tedak sinten
# 1301855750331883520 2020-09-04 19:12:52 SE Asia Standard Time <ShopeeID> Mimpi apa dapet pantun dari Yerin & SinB! Denger-denger GFRIEND bakal seru-seruan bareng kita di Shopee 99 Super Shopping Day TV Show! Hari Rabu 9 Sep, LIVE di Shopee Live, SCTV, RCTI, INDOSIAR, MNCTV pk. 19.00 WIB! Kira-kira kalian mau liat duo GFRIEND siapa? #ShopeeDuoinGFRIEND
# 1301320903754543105 2020-09-03 07:47:35 SE Asia Standard Time <gemintangnova> tedak sinten kalo ga salah, biasanya adatnya buat bayi
# 1301319999995301890 2020-09-03 07:44:00 SE Asia Standard Time <muhamadamang_> Tedak sinten
# 1301319958501097472 2020-09-03 07:43:50 SE Asia Standard Time <bucinnyakult> Tedak sinten
# 1301318893072388096 2020-09-03 07:39:36 SE Asia Standard Time <shfannabe> Tedak sinten, tapi di tempatku nyebutnya pitonan
# 1301318456533422080 2020-09-03 07:37:52 SE Asia Standard Time <yourlovelyrosie> Tedak sinten
# ...

# %%
import pandas as pd
import json
import nltk
from nltk.corpus import stopwords
import re
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %%
df = pd.read_json ('Data/Indonesia(Tedak Sinten).json', lines = True)
df.head()
# Out:
#                     id      conversation_id          created_at       date  \
# 0  1301333219296460800  1301317486151782400 2020-09-03 01:36:31 2020-09-03
# 1  1301855750331883520  1301855750331883520 2020-09-04 12:12:52 2020-09-04
# 2  1301320903754543105  1301317486151782400 2020-09-03 00:47:35 2020-09-03
# 3  1301319999995301890  1301317486151782400 2020-09-03 00:44:00 2020-09-03
# 4  1301319958501097472  1301317486151782400 2020-09-03 00:43:50 2020-09-03
#
#        time               timezone              user_id       username  \
# 0  08:36:31  SE Asia Standard Time  1057517144513097728      ambrosya1
# 1  19:12:52  SE Asia Standard Time           2983890506       shopeeid
# 2  07:47:35  SE Asia Standard Time   873911322160766976  gemintangnova
# 3  07:44:00  SE Asia Standard Time           3013225207  muhamadamang_
# 4  07:43:50  SE Asia Standard Time  1025023127892291584   bucinnyakult
#
#                name place  ... geo source user_rt_id user_rt  retweet_id  \
# ...

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split, KFold
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
import matplotlib
from matplotlib import pyplot as plt
# import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
df1 = df[['id', 'tweet']]
df1.head
# Out:
# <bound method NDFrame.head of                       id                                              tweet
# 0    1301333219296460800                                       tedak sinten
# 1    1301855750331883520  Mimpi apa dapet pantun dari Yerin & SinB! Deng...
# 2    1301320903754543105  tedak sinten kalo ga salah, biasanya adatnya b...
# 3    1301319999995301890                                       Tedak sinten
# 4    1301319958501097472                                       Tedak sinten
# ..                   ...                                                ...
# 981   670814336139534336  Lihat... Dirga mirip siapa? #dirgantara #8bula...
# 982   670544308114554880  Tedak sinten #TurunTanah #Weekend #Bismillah ð...
# 983   665785380940218368  Tedak sinten Dirga 8 bulan #dirgantara #tedaks...
# 984   655355828728438784  From tedak sinten adek firdaus #wibiephoto #po...
# 985   642909134245883904  @PregnancyID @FisherPrice_ID saat jalan pertam...
#
# [986 rows x 2 columns]>

# %%
#Hapus Tanda Baca

df1['tweet'] = df1['tweet'].apply(remove_punctuation)
df1.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-d213aaf7e60d> in <module>
#       1 #Hapus Tanda Baca
#       2
# ----> 3 df1['tweet'] = df1['tweet'].apply(remove_punctuation)
#       4 df1.head(10)
#
# NameError: name 'remove_punctuation' is not defined

# %%
#Jadiin Huruf Kecil

df1['tweet'] = [entry.lower() for entry in df1['tweet']]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df1.head()
# Out:
#                     id                                              tweet
# 0  1301333219296460800                                       tedak sinten
# 1  1301855750331883520  mimpi apa dapet pantun dari yerin & sinb! deng...
# 2  1301320903754543105  tedak sinten kalo ga salah, biasanya adatnya b...
# 3  1301319999995301890                                       tedak sinten
# 4  1301319958501097472                                       tedak sinten

# %%
#Tokenisasi

df1['tweet']= [word_tokenize(entry) for entry in df1['tweet']]
df1.head()
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-29-c53642d70dc8> in <module>
#       1 #Tokenisasi
#       2
# ----> 3 df1['tweet']= [word_tokenize(entry) for entry in df1['tweet']]
#       4 df1.head()
#
# <ipython-input-29-c53642d70dc8> in <listcomp>(.0)
#       1 #Tokenisasi
#       2
# ----> 3 df1['tweet']= [word_tokenize(entry) for entry in df1['tweet']]
#       4 df1.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\tokenize\__init__.py in word_tokenize(text, language, preserve_line)
#     142     :type preserve_line: bool
#     143     """
# --> 144     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     145     return [
#     146         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\tokenize\__init__.py in sent_tokenize(text, language)
# ...

# %%
#Hapus Karakter Non Alfabet

for index,entry in enumerate(df1['tweet']):
    Final_words = []
    word_Lemmatized = WordNetLemmatizer()
    for word, tag in pos_tag(entry):
        if word.isalpha():
            word_Final = word_Lemmatized.lemmatize(word,tag_map[tag[0]])
            Final_words.append(word_Final)
    data.loc[index,'text_final'] = str(Final_words)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-30-b989c7290218> in <module>
#       2     Final_words = []
#       3     word_Lemmatized = WordNetLemmatizer()
# ----> 4     for word, tag in pos_tag(entry):
#       5         if word.isalpha():
#       6             word_Final = word_Lemmatized.lemmatize(word,tag_map[tag[0]])
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\tag\__init__.py in pos_tag(tokens, tagset, lang)
#     159     :rtype: list(tuple(str, str))
#     160     """
# --> 161     tagger = _get_tagger(lang)
#     162     return _pos_tag(tokens, tagset, tagger, lang)
#     163
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\tag\__init__.py in _get_tagger(lang)
#     105         tagger.load(ap_russian_model_loc)
#     106     else:
# --> 107         tagger = PerceptronTagger()
#     108     return tagger
#     109
#
# ...

# %%
love = 0
while (love < 1):
    print('The count is:', love)
    love = love + 1
print('Good bye!')
# Out:
# The count is: 0
# Good bye!
